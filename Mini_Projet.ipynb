# %%
#Conception architecturale d'une application de gestion de taches
##1. Introduction

Notre projet consiste a concevoir une application de gestion de taches nommée Todo-list qui sera capable de créer , supprimer, ajouter, modifier une taches .


## 2.Objectifs



## 3.Besoin fonctionnels



## 4.Besoin non-fonctionnels



## 5.Contrainte techniques


## 6.Architecture du logiciel
